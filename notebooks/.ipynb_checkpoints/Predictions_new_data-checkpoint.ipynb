# %%
#Deserialize
import pickle
import pandas as pd
from src.modules.paths import get_project_root
from src.core.features.utils import feature_pipeline, add_domain_features
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
with open("wow.pickle" ,'rb') as f:
    model = pickle.load(f)

# %%
def backtest(df: pd.DataFrame, model, threshold, target, fee, columns_features):
    """"""
    if target not in df.columns:
        raise KeyError(f"{target} not included in columns")
        
    df_backtesting = df[[target, "open"]].copy()
    df_backtesting["preds"] = model.predict(df[columns_features])
    
    df_backtesting = add_actions(df_backtesting, threshold)
    return evaluate(df_backtesting, fee)
    
    
    
def add_actions(df_backtesting, threshold):
    next_action = "buy"
    df_backtesting["action"] = None
    df_backtesting["sum"] = None
    for index, row in df_backtesting.iterrows():
        if (-row["preds"] > threshold) and (next_action=="buy"):
            df_backtesting.loc[df_backtesting.index==index, "action"] = "buy"
            next_action = "sell"
        elif (-row["preds"] < -threshold) and (next_action=="sell"):
            df_backtesting.loc[df_backtesting.index==index, "action"] = "sell"
            next_action = "buy"
    return df_backtesting

def evaluate(df_backtesting, fee):
    df_backtesting["sum"] = None
    df_backtesting.loc[(df_backtesting.action=="buy"), "sum"] = -df_backtesting[df_backtesting.action=="buy"].open*(1+fee)
    df_backtesting.loc[(df_backtesting.action=="sell"), "sum"] = df_backtesting[df_backtesting.action=="sell"].open*(1-fee)
    if df_backtesting[df_backtesting.action.notnull()].tail(1).action.values[0]=="buy":
        df_backtesting.loc[df_backtesting[df_backtesting.action.notnull()].tail(1).index, ["sum", "action"]] = None
    if df_backtesting[df_backtesting.action.notnull()].tail(1).action.values[0]=="buy":
        raise ValueError("last action cannot be buy")
    n_trades = df_backtesting["sum"].notnull().sum()
    profit = df_backtesting["sum"].sum()/df_backtesting["open"].mean()
    return n_trades, profit

# %%
cut_off_date ="2021-11-07 21:28:00"
columns_features = [col for col in feature_pipeline(pd.read_csv(get_project_root() / "data" / "historical" / "etheur.csv"), include_target=True, target_list=[10])[0].columns if col.startswith("feature")]

# %%
# test real data
#eth
list_results=[]
for pair_name in ["xlmeur", "bcheur","compeur","xdgeur", "etheur", "algoeur", "bateur", "adaeur","xrpeur"]:
    df = pd.read_csv(get_project_root() / "data" / "historical" / f"{pair_name}.csv")
    df = df[df.date>cut_off_date]
    df, _=feature_pipeline(df, include_target=True, target_list=[10])
    for threshold in [0.5,1.5, 2.,2.5,3, 3.5,4]:
        n_trades, profit = backtest(df=df, model=model, threshold=threshold, target="target_10", fee=0.0024, columns_features=columns_features)
        print(threshold, pair_name, n_trades, profit)
        list_results.append((threshold, pair_name, n_trades, profit))
    
    #backtest(df=df, model=model, threshold=2.5, target="target_10", fee=0.0024, columns_features=columns_features)
# Out:
# 0.5 xlmeur 1108 -0.8945172716652788
# 1.5 xlmeur 356 0.2253572235385924
# 2.0 xlmeur 238 0.22178491747792
# 2.5 xlmeur 164 0.23690382552593828
# 3 xlmeur 110 0.30959911126029027
# 3.5 xlmeur 76 0.24094686608467064
# 4 xlmeur 58 0.21079881372007794
# 0.5 bcheur 762 -0.6970131933511953
# 1.5 bcheur 198 0.0418298511319431
# 2.0 bcheur 118 0.15514254326511606
# 2.5 bcheur 78 0.13322692752900955
# 3 bcheur 58 0.11757836252187132
# 3.5 bcheur 38 0.021468207503543432
# 4 bcheur 32 -0.028955724379116504
# 0.5 compeur 180 -0.03671590644655902
# 1.5 compeur 68 0.014182498115850416
# 2.0 compeur 50 0.040239231534246814
# 2.5 compeur 34 0.05045292360536088
# 3 compeur 28 0.04382125554078311
# 3.5 compeur 22 0.07552147836653032
# 4 compeur 18 0.024927500938395485
# 0.5 xdgeur 1240 -1.055325239313392
# 1.5 xdgeur 362 0.19364868000527283
# 2.0 xdgeur 234 0.28749572206217644
# 2.5 xdgeur 154 0.3202551424631018
# 3 xdgeur 104 0.2344587684211806
# 3.5 xdgeur 92 0.13783240265450677
# 4 xdgeur 78 0.10980518139489635
# 0.5 etheur 1520 -1.7440455642346624
# 1.5 etheur 286 -0.09397079898055222
# 2.0 etheur 146 -0.0518335420235776
# 2.5 etheur 62 0.0029404131674311677
# 3 etheur 30 -0.02842567136592022
# 3.5 etheur 16 -0.007406148562622863
# 4 etheur 14 -0.00024066826857100474
# 0.5 algoeur 1372 -0.3286253838974678
# 1.5 algoeur 636 0.6086013714301304
# 2.0 algoeur 474 0.7344593920318641
# 2.5 algoeur 344 0.8184633876532188
# 3 algoeur 266 0.806040824800414
# 3.5 algoeur 208 0.69886545588462
# 4 algoeur 166 0.6703163644933032
# 0.5 bateur 1094 0.1839730715545911
# 1.5 bateur 602 0.8393962040452587
# 2.0 bateur 462 0.9907518081785467
# 2.5 bateur 366 0.8787871782653792
# 3 bateur 282 0.9661272513631926
# 3.5 bateur 224 0.8040270518167557
# 4 bateur 188 0.7979735471487821
# 0.5 adaeur 1856 -1.5696907718717004
# 1.5 adaeur 534 0.2682461222540228
# 2.0 adaeur 316 0.3684834261703452
# 2.5 adaeur 198 0.36316035410043834
# 3 adaeur 124 0.26717976727451204
# 3.5 adaeur 84 0.34135462667797223
# 4 adaeur 58 0.33957293838105196
# 0.5 xrpeur 1852 -1.7245035532636037
# 1.5 xrpeur 516 0.15245988981711178
# 2.0 xrpeur 286 0.3091708128447723
# 2.5 xrpeur 184 0.24559951009622574
# 3 xrpeur 118 0.26348476872030846
# 3.5 xrpeur 82 0.16999060715459602
# 4 xrpeur 48 0.11158155523974467

# %%
pd.DataFrame(list_results)
# Out:
#       0       1     2         3
# 0   0.5  xlmeur  1108 -0.894517
# 1   1.5  xlmeur   356  0.225357
# 2   2.0  xlmeur   238  0.221785
# 3   2.5  xlmeur   164  0.236904
# 4   3.0  xlmeur   110  0.309599
# ..  ...     ...   ...       ...
# 58  2.0  xrpeur   286  0.309171
# 59  2.5  xrpeur   184  0.245600
# 60  3.0  xrpeur   118  0.263485
# 61  3.5  xrpeur    82  0.169991
# 62  4.0  xrpeur    48  0.111582
#
# [63 rows x 4 columns]

# %%
df_test = pd.read_csv(get_project_root() / "data" / "historical" / f"bateur.csv")
df_test = df_test[df_test.date>cut_off_date]
df_test, _=feature_pipeline(df_test, include_target=True, target_list=[10])
n_trades, profit = backtest(df=df_test, model=model, threshold=2.5, target="target_10", fee=0.0024, columns_features=columns_features)

# %%
columns_features = [col for col in df_eth.columns if col.startswith("feature")]

# %%
backtest(df=df, model=model, threshold=2.5, target="target_10", fee=0.0024, columns_features=columns_features)
# Out:
# (62, 0.002940228588493385)

# %%
plt.figure(figsize=(15,5))
preds = model.predict(df_test[columns_features])
target = df_test["target_10"]*1000
plt.plot(preds*10, label="preds")
plt.plot(target.values, label="target")
#plt.xlim([0,10000])
plt.legend()
plt.title("test")
plt.show()
print(pd.DataFrame(data={"preds": preds, "target": target}).corr().values[0][1])
print(r2_score(target,preds ))
# Out:
# 0.20992688480292376
# 0.04401735567394216

# %%
df_backtesting = df_test.copy()
df_backtesting["preds"] = model.predict(df_test[columns_features])/1000

# %%
df_backtesting[["target_10", "preds"]].plot()
# Out:
# <AxesSubplot:>

# %%
# backtesting
threshold = 0.0025
next_action = "buy"
df_backtesting["action"] = None
df_backtesting["sum"] = None
for index, row in df_backtesting.iterrows():
    if (-row["preds"] > threshold) and (next_action=="buy"):
        df_backtesting.loc[df_backtesting.index==index, "action"] = "buy"
        next_action = "sell"
    elif (-row["preds"] < -threshold) and (next_action=="sell"):
        df_backtesting.loc[df_backtesting.index==index, "action"] = "sell"
        next_action = "buy"

# %%
df_backtesting.preds.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
#plt.plot(df_backtesting.preds)
#plt.plot(df_backtesting.target_10)
plt.figure(figsize=(20,5))
plt.plot(df_backtesting.open)
plt.plot(df_backtesting[df_backtesting.action=="sell"].open, ">r", label="actual sell")
plt.plot(df_backtesting[df_backtesting.action=="buy"].open, ">g", label="actual buy")
plt.legend()
plt.show()
plt.figure(figsize=(20,5))
plt.plot(df_backtesting.open, "-")
plt.plot(df_backtesting[-df_backtesting.preds> threshold].open, ">g", label="predicted buy")
plt.plot(df_backtesting[-df_backtesting.preds<-threshold].open, ">r", label="predicted sell")
#plt.xlim([0,1000])
#plt.ylim([4050,4150])
plt.legend()
plt.show()

# %%
df_backtesting["sum"] = None
fee = 0.0024
df_backtesting.loc[(df_backtesting.action=="buy"), "sum"] = -df_backtesting[df_backtesting.action=="buy"].open*(1+fee)
df_backtesting.loc[(df_backtesting.action=="sell"), "sum"] = df_backtesting[df_backtesting.action=="sell"].open*(1-fee)

# %%
if df_backtesting[df_backtesting.action.notnull()].tail(1).action.values[0]=="buy":
    df_backtesting.loc[df_backtesting[df_backtesting.action.notnull()].tail(1).index, ["sum", "action"]] = None
if df_backtesting[df_backtesting.action.notnull()].tail(1).action.values[0]=="buy":
    raise ValueError("last action cannot be buy")
df_backtesting["sum"].notnull().sum()
# Out:
# 366

# %%
df_backtesting[df_backtesting.action.notnull()].tail(1)["action"]
# Out:
# 11874    sell
# Name: action, dtype: object

# %%
df_backtesting["sum"].sum()
# Out:
# 0.8774468720000177

# %%
df.date.max()
# Out:
# '2021-11-16 13:54:00'

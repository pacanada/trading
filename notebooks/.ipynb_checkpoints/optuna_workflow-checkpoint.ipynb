# %%
import os
import gdown
import pandas as pd
import xgboost as xgb
import optuna
from sklearn.metrics import r2_score
def download_training_data(id_file, output_folder, output_name):
    url = f"https://drive.google.com/uc?id={id_file}"
    os.makedirs(output_folder, exist_ok=True)
    gdown.download(url, output_folder + output_name, quiet=False)
    
def load_data(input_folder, input_name):
    df = pd.read_feather(input_folder + input_name)
    df["target_10_multiplied"] = df["target_10"]*1000
    # training, test, validation
    return df[df.type=="training"], df[df.type=="validation"], df[df.type=="validation_unseen"]

# %%
file, folder = "training_all_crypto.feather", "temp/"

# %%
# Download data

download_training_data("15VkzDb8sfWTDOl44ODmkNS20KEszWUb-", folder, file)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15VkzDb8sfWTDOl44ODmkNS20KEszWUb-
# To: /Users/pablocanadapereira/Desktop/Projects/trading/trading/notebooks/temp/training_all_crypto.feather
# 100%|██████████| 398M/398M [00:09<00:00, 41.1MB/s]

# %%
df_training, df_val, df_val_unseen = load_data(folder, file)
columns_features = [col for col in df_training.columns if col.startswith("feature")]
#columns_target = [col for col in df_training.columns if col.startswith("target")]
columns_target = ["target_10_multiplied"]

# %%
def objective(trial):
    # 1. Suggest values of the hyperparameters using a trial object.
    param = {
        'booster': trial.suggest_categorical('booster', ['gbtree', 'gblinear', 'dart']),
        'lambda': trial.suggest_float('lambda', 1e-8, 1.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-8, 1.0, log=True),
        "n_estimators": trial.suggest_int("n_estimators", 1,100, log=True),
        "max_depth": trial.suggest_int("max_depth", 2,20),
        "learning_rate": trial.suggest_float("learning_rate", 0.0001,0.5, log=True)
        "subsample": trial.suggest_float("subsample", 0.5,1),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0,1),
    }

    # 2. Define model
    model =xgb.XGBRegressor(**param,
    n_jobs=-1,
    colsample_bytree=0.1,
    )
    # 3. Train
    model.fit(df_training[columns_features].astype("float32"), df_training[columns_target].astype("float32"))
    # 4. Evaluate
    df_val_eval = pd.DataFrame(index=df_val.index)
    df_val_eval["target"] = df_val[columns_target]
    df_val_eval["preds"] = model.predict(df_val[columns_features])
    #data={"target": df_val[columns_target].values], "preds": [model.predict(df_val[columns_features])]})
    corr_val = df_val_eval.corr().values[0][1]
    r2 = r2_score(df_val_eval.target, df_val_eval.preds )
    print(corr_val, r2)
    return 0.3*corr_val + 0.7*r2

# 3. Create a study object and optimize the objective function.
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=20)
# Out:
# [I 2021-11-09 20:38:14,178] A new study created in memory with name: no-name-13fceabb-b5d7-4e4b-bdde-a6ca586c0e4a
# [I 2021-11-09 20:38:19,972] Trial 0 finished with value: 0.10544255053050292 and parameters: {'booster': 'dart', 'lambda': 0.8326328325245919, 'alpha': 0.6499096903122968, 'n_estimators': 5, 'max_depth': 19, 'learning_rate': 0.02028330503397493}. Best is trial 0 with value: 0.10544255053050292.
# 0.10544255053050292 0.0011069969214011488
# [20:38:20] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:541:
# Parameters: { colsample_bytree, max_depth, subsample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-11-09 20:38:21,679] Trial 1 finished with value: 0.07531013997239465 and parameters: {'booster': 'gblinear', 'lambda': 0.004229699702974778, 'alpha': 5.515361685007017e-06, 'n_estimators': 15, 'max_depth': 15, 'learning_rate': 0.14078847865598265}. Best is trial 0 with value: 0.10544255053050292.
# 0.07531013997239465 0.001170483571712011
# [I 2021-11-09 20:38:39,954] Trial 2 finished with value: 0.04900530205534414 and parameters: {'booster': 'gbtree', 'lambda': 0.0008133746354294298, 'alpha': 3.759434378869993e-08, 'n_estimators': 26, 'max_depth': 17, 'learning_rate': 0.015564297573167952}. Best is trial 0 with value: 0.10544255053050292.
# 0.04900530205534414 -0.003226431511919481
# [20:38:40] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:541:
# Parameters: { colsample_bytree, max_depth, subsample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-11-09 20:38:40,958] Trial 3 finished with value: -0.03801536755633726 and parameters: {'booster': 'gblinear', 'lambda': 0.004885094529136594, 'alpha': 0.00023018087186811985, 'n_estimators': 1, 'max_depth': 16, 'learning_rate': 0.03577239240790474}. Best is trial 0 with value: 0.10544255053050292.
# -0.03801536755633726 -0.0007010012555763723
# [I 2021-11-09 20:38:43,613] Trial 4 finished with value: 0.14189025207050582 and parameters: {'booster': 'gbtree', 'lambda': 0.04745436723449504, 'alpha': 0.00014770326380909602, 'n_estimators': 2, 'max_depth': 13, 'learning_rate': 0.02757083636901431}. Best is trial 4 with value: 0.14189025207050582.
# 0.14189025207050582 0.0005092981112788664
# [I 2021-11-09 20:39:32,172] Trial 5 finished with value: 0.08896574075099942 and parameters: {'booster': 'gbtree', 'lambda': 0.0033627653309337346, 'alpha': 3.4476109171080724e-07, 'n_estimators': 71, 'max_depth': 16, 'learning_rate': 0.0022023908136506384}. Best is trial 4 with value: 0.14189025207050582.
# 0.08896574075099942 0.0018764228307927011
# [I 2021-11-09 20:39:41,740] Trial 6 finished with value: 0.13794956883724901 and parameters: {'booster': 'dart', 'lambda': 0.10619458216752481, 'alpha': 0.0032477840864686166, 'n_estimators': 13, 'max_depth': 13, 'learning_rate': 0.002922411429278997}. Best is trial 4 with value: 0.14189025207050582.
# 0.13794956883724901 -0.002886068722896873
# [I 2021-11-09 20:39:51,883] Trial 7 finished with value: 0.16041906987519713 and parameters: {'booster': 'dart', 'lambda': 0.0004000664933445073, 'alpha': 0.030750802183222795, 'n_estimators': 43, 'max_depth': 3, 'learning_rate': 0.000990623016878147}. Best is trial 7 with value: 0.16041906987519713.
# 0.16041906987519713 -0.003301902336488194
# [I 2021-11-09 20:39:55,986] Trial 8 finished with value: 0.08424566138436855 and parameters: {'booster': 'gbtree', 'lambda': 0.0034859951018513064, 'alpha': 0.0006776602022070862, 'n_estimators': 4, 'max_depth': 13, 'learning_rate': 0.3797160961188431}. Best is trial 7 with value: 0.16041906987519713.
# 0.08424566138436855 -0.07516996106397889
# [I 2021-11-09 20:39:58,441] Trial 9 finished with value: 0.1529223269400776 and parameters: {'booster': 'gbtree', 'lambda': 0.0004353270201619998, 'alpha': 5.1025114139443744e-08, 'n_estimators': 1, 'max_depth': 6, 'learning_rate': 0.0038313921955915623}. Best is trial 7 with value: 0.16041906987519713.
# 0.1529223269400776 -0.006159271114516418
# [I 2021-11-09 20:40:16,673] Trial 10 finished with value: 0.13853640888483476 and parameters: {'booster': 'dart', 'lambda': 1.7815616860159458e-06, 'alpha': 0.12198302268091943, 'n_estimators': 90, 'max_depth': 2, 'learning_rate': 0.0001729333003099926}. Best is trial 7 with value: 0.16041906987519713.
# 0.13853640888483476 -0.00555127426313029
# [I 2021-11-09 20:40:19,067] Trial 11 finished with value: 0.1536051556082164 and parameters: {'booster': 'dart', 'lambda': 8.202753580944537e-06, 'alpha': 0.007924109533413442, 'n_estimators': 1, 'max_depth': 5, 'learning_rate': 0.00028763692458616313}. Best is trial 7 with value: 0.16041906987519713.
# 0.1536051556082164 -0.006484249953709442
# [I 2021-11-09 20:40:30,524] Trial 12 finished with value: 0.14162134043503002 and parameters: {'booster': 'dart', 'lambda': 5.270907688048967e-06, 'alpha': 0.020631051360022874, 'n_estimators': 30, 'max_depth': 6, 'learning_rate': 0.0002865064401045732}. Best is trial 7 with value: 0.16041906987519713.
# 0.14162134043503002 -0.005806855052497895
# [I 2021-11-09 20:40:32,910] Trial 13 finished with value: 0.13142278086717038 and parameters: {'booster': 'dart', 'lambda': 1.2905613775715867e-08, 'alpha': 0.013625803700095975, 'n_estimators': 2, 'max_depth': 4, 'learning_rate': 0.0007324646027334447}. Best is trial 7 with value: 0.16041906987519713.
# 0.13142278086717038 -0.006383872804049506
# [I 2021-11-09 20:40:55,154] Trial 14 finished with value: 0.1092458730277717 and parameters: {'booster': 'dart', 'lambda': 2.0979507718431452e-05, 'alpha': 0.9135260325294947, 'n_estimators': 41, 'max_depth': 9, 'learning_rate': 0.0007629410642780955}. Best is trial 7 with value: 0.16041906987519713.
# 0.1092458730277717 -0.004309084813598263
# [I 2021-11-09 20:41:01,228] Trial 15 finished with value: 0.1483775755281853 and parameters: {'booster': 'dart', 'lambda': 2.0423007695274497e-07, 'alpha': 1.5079675615195924e-05, 'n_estimators': 9, 'max_depth': 9, 'learning_rate': 0.00010917778590901789}. Best is trial 7 with value: 0.16041906987519713.
# 0.1483775755281853 -0.006415405414009312
# [I 2021-11-09 20:41:03,462] Trial 16 finished with value: 0.13276329152920413 and parameters: {'booster': 'dart', 'lambda': 5.4831474168080936e-05, 'alpha': 0.0029126301295194596, 'n_estimators': 2, 'max_depth': 3, 'learning_rate': 0.0006718585044428681}. Best is trial 7 with value: 0.16041906987519713.
# 0.13276329152920413 -0.0064115172546199695
# [20:41:04] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:541:
# Parameters: { colsample_bytree, max_depth, subsample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [I 2021-11-09 20:41:04,688] Trial 17 finished with value: -0.0408118122382508 and parameters: {'booster': 'gblinear', 'lambda': 6.76444163437426e-07, 'alpha': 0.0653244288969272, 'n_estimators': 4, 'max_depth': 6, 'learning_rate': 0.00032375231833800755}. Best is trial 7 with value: 0.16041906987519713.
# -0.0408118122382508 -0.005510240054667603
# [I 2021-11-09 20:41:15,314] Trial 18 finished with value: 0.13586756830347627 and parameters: {'booster': 'dart', 'lambda': 0.00013943335397669887, 'alpha': 1.6395307845744655e-05, 'n_estimators': 19, 'max_depth': 9, 'learning_rate': 0.0014024205149865776}. Best is trial 7 with value: 0.16041906987519713.
# 0.13586756830347627 -0.004367921439587086
# [I 2021-11-09 20:41:18,984] Trial 19 finished with value: 0.14423528799926189 and parameters: {'booster': 'dart', 'lambda': 7.308419511168111e-08, 'alpha': 0.0025838422125230845, 'n_estimators': 7, 'max_depth': 4, 'learning_rate': 0.01092919390667865}. Best is trial 7 with value: 0.16041906987519713.
# 0.14423528799926189 -0.0009518547041542647

# %% [markdown]
# # Train final model and check

# %%
from src.core.features.utils import feature_pipeline, add_domain_features
import matplotlib.pyplot as plt

# %%
best_params = {'booster': 'gblinear',
 'lambda': 1.0316183369767604e-08,
 'alpha': 5.146496638539848e-05,
 'n_estimators': 4,
 'max_depth': 3}

# %%
best_params = study.best_trial.params
print(best_params)
# Out:
# {'booster': 'dart', 'lambda': 0.0004000664933445073, 'alpha': 0.030750802183222795, 'n_estimators': 43, 'max_depth': 3, 'learning_rate': 0.000990623016878147}

# %%
# double check
df_training_sampled = df_training.iloc[:-1000]
df_test_init = df_training.iloc[-1000:][["open", "high", "low", "close", "vwap", "volume"]]

# %%
df_test, _=feature_pipeline(df_test_init, include_target=False)

# %%
#compute_RSI(df_test_init, "open", 100) # it is not
#add_domain_features(df_test_init, "open").iloc[-1:].isnull().sum()

# %%
df_test
# Out:
#         open     high      low    close     vwap        volume  open_norm  \
# 0    1.09385  1.09385  1.09385  1.09385  0.00000      0.000000        1.0
# 1    1.09201  1.09236  1.09122  1.09223  1.09232   2732.373154        1.0
# 2    1.09053  1.09074  1.09053  1.09074  1.09059    919.207190        1.0
# 3    1.09000  1.09000  1.08847  1.08847  1.08853   3325.667492        1.0
# 4    1.08895  1.08895  1.08878  1.08878  1.08886    206.968200        1.0
# ..       ...      ...      ...      ...      ...           ...        ...
# 595  1.08850  1.08850  1.08850  1.08850  1.08850     15.000000        1.0
# 596  1.08900  1.08947  1.08843  1.08947  1.08904  10442.923345        1.0
# 597  1.08956  1.09022  1.08956  1.09022  1.09015    136.881694        1.0
# 598  1.08984  1.08986  1.08889  1.08897  1.08950   2561.313489        1.0
# 599  1.08839  1.08867  1.08836  1.08867  1.08838   1393.121619        1.0
#
#      close_norm  high_norm  low_norm  ...  feature_domain_28  \
# 0      1.000000   1.000000  1.000000  ...          -0.005021
# 1      1.000201   1.000321  0.999277  ...          -0.006912
# 2      1.000193   1.000193  1.000000  ...          -0.005272
# 3      0.998596   1.000000  0.998596  ...          -0.003520
# 4      0.999844   1.000000  0.999844  ...          -0.002802
# ..          ...        ...       ...  ...                ...
# 595    1.000000   1.000000  1.000000  ...          -0.001074
# 596    1.000432   1.000432  0.999477  ...           0.001610
# 597    1.000606   1.000606  1.000000  ...          -0.001567
# 598    0.999202   1.000018  0.999128  ...           0.001231
# 599    1.000257   1.000257  0.999972  ...          -0.000560
#
#      feature_domain_29  feature_domain_30  feature_domain_31  \
# 0             0.000640           0.002401           0.004030
# 1            -0.003504           0.000137           0.002773
# 2            -0.008041          -0.001346           0.001451
# 3            -0.008739          -0.004293          -0.000110
# 4            -0.006713          -0.003869          -0.000376
# ..                 ...                ...                ...
# 595           0.001242           0.003226           0.000018
# 596           0.000818           0.004075           0.001720
# 597          -0.000101           0.003417           0.002337
# 598           0.002382           0.002290           0.003776
# 599          -0.002639           0.001343           0.002940
#
#      feature_domain_32  feature_domain_33  feature_domain_34  \
# 0             0.007154           0.011148          -0.006151
# 1             0.005460           0.008627          -0.003831
# 2             0.004763           0.004245          -0.005898
# 3             0.002124           0.003813          -0.004139
# 4             0.000938           0.003400          -0.006451
# ..                 ...                ...                ...
# 595          -0.000560          -0.004991          -0.001825
# 596           0.000220          -0.004843          -0.000532
# 597           0.000735          -0.002691           0.000965
# 598           0.002189          -0.001548           0.001802
# 599           0.000763          -0.002703           0.001472
#
#      feature_domain_35  feature_domain_36  feature_domain_37
# 0             0.039159           0.032440           0.033924
# 1             0.037411           0.030869           0.032975
# 2             0.036094           0.029968           0.031332
# 3             0.035629           0.027856           0.030246
# 4             0.034622           0.027224           0.028145
# ..                 ...                ...                ...
# 595          -0.003871          -0.018131          -0.019281
# 596          -0.003441          -0.016385          -0.019281
# 597          -0.002417          -0.015176          -0.019192
# 598          -0.002508          -0.016239          -0.020316
# 599          -0.003260          -0.016873          -0.022779
#
# [600 rows x 128 columns]

# %%
df_test_init
# Out:
#            open     high      low    close     vwap        volume
# 582082  1.05796  1.05799  1.05720  1.05762  1.05773   2753.188867
# 582083  1.05715  1.05794  1.05538  1.05794  1.05619  51378.009795
# 582084  1.05740  1.05757  1.05641  1.05757  1.05724  29171.841268
# 582085  1.05800  1.05894  1.05798  1.05894  1.05854  51930.719416
# 582086  1.05914  1.05986  1.05888  1.05889  1.05971  11602.210838
# ...         ...      ...      ...      ...      ...           ...
# 583077  1.08850  1.08850  1.08850  1.08850  1.08850     15.000000
# 583078  1.08900  1.08947  1.08843  1.08947  1.08904  10442.923345
# 583079  1.08956  1.09022  1.08956  1.09022  1.09015    136.881694
# 583080  1.08984  1.08986  1.08889  1.08897  1.08950   2561.313489
# 583081  1.08839  1.08867  1.08836  1.08867  1.08838   1393.121619
#
# [1000 rows x 6 columns]

# %%
final_model =xgb.XGBRegressor(**best_params,
    #learning_rate=0.1,
    n_jobs=-1,
    subsample=0.9,
    colsample_bytree=0.1,
    )
final_model.fit(df_training_sampled[columns_features].astype("float32"), df_training_sampled[columns_target].astype("float32"))
# Out:
# XGBRegressor(alpha=0.030750802183222795, base_score=0.5, booster='dart',
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.1,
#              gamma=0, gpu_id=-1, importance_type='gain',
#              interaction_constraints='', lambda=0.0004000664933445073,
#              learning_rate=0.000990623016878147, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=43, n_jobs=-1, num_parallel_tree=1, random_state=0,
#              reg_alpha=0.0307508018, reg_lambda=0.000400066492,
#              scale_pos_weight=1, subsample=0.9, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
plt.figure(figsize=(15,5))
preds = final_model.predict(df_test[columns_features])
target = df_training.iloc[-600:].reset_index()["target_10"]*1000
plt.plot(preds*10, label="preds")
plt.plot(target, label="target")
plt.legend()
plt.show()
print(pd.DataFrame(data={"preds": preds, "target": target}).corr().values[0][1])
print(r2_score(target,preds ))
# Out:
# 0.20151586074123595
# -0.007174575672761918

# %%
df_plot_test = get_df_plot(df_val, final_model, pytorch=False)
plot_results(df_plot_test)
# Out:
# corr:  0.1594285070451713
# r2:  -0.0031819469613734164

# %%
final_model =xgb.XGBRegressor(**study.best_trial.params,
    learning_rate=0.1,
    n_jobs=-1,
    subsample=0.9,
    colsample_bytree=0.1,
    )
    # 3. Train
final_model.fit(df_training[columns_features].astype("float32"), df_training[columns_target].astype("float32"))
# Out:
# [19:35:12] WARNING: /opt/concourse/worker/volumes/live/7a2b9f41-3287-451b-6691-43e9a6c0910f/volume/xgboost-split_1619728204606/work/src/learner.cc:541:
# Parameters: { colsample_bytree, max_depth, subsample } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBRegressor(alpha=5.146496638539848e-05, base_score=0.5, booster='gblinear',
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.1, gamma=None, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              lambda=1.0316183369767604e-08, learning_rate=0.1,
#              max_delta_step=None, max_depth=3, min_child_weight=None,
#              missing=nan, monotone_constraints=None, n_estimators=4, n_jobs=-1,
#              num_parallel_tree=None, random_state=0, reg_alpha=0, reg_lambda=0,
#              scale_pos_weight=1, subsample=0.9, tree_method=None,
#              validate_parameters=1, verbosity=None)

# %%
def get_df_plot(df, model, pytorch=True):
    df_plot = df.reset_index()[columns_target].rename(columns={columns_target[0]:"target"})
    if pytorch:
        df_plot["preds"] = model.predict(df, columns_features, cpu_dev)
    else:
        df_plot["preds"] = model.predict(df[columns_features])
                                    
    return df_plot
def plot_results(df, xlim=None):
    fig, axs = plt.subplots(1,2,figsize=(16,5), gridspec_kw={'width_ratios': [3, 1]})
    axs[0].plot(df["preds"], label="preds")
    axs[0].plot(df["target"],label= "target", alpha=0.5)
    if xlim:
        axs[0].set_xlim(xlim)
    axs[0].legend()
    axs[1].plot(df.preds, df.target, "o", alpha=0.5)
    print("corr: ", df.corr().values[0][1])
    print("r2: ", r2_score(df.target,df.preds ))

# %%
df_plot_val = get_df_plot(df_val, final_model, pytorch=False)
df_plot_val_unseen = get_df_plot(df_val_unseen, final_model, pytorch=False)

# %%
plot_results(df_plot_val)
# Out:
# corr:  0.30000491070842966
# r2:  0.08820782881052547

# %%
plot_results(df_plot_val_unseen)
# Out:
# corr:  0.34681178644103405
# r2:  0.10764870659901982

# %%
plot_results(df_plot_val_unseen, xlim=[100,1000])

# %%
import matplotlib.pyplot as plt
df_plot_val = get_df_plot(df_validation, model, pytorch=False)
